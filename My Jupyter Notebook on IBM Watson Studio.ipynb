# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio
# Jupyter does no longer support Heading, instead I'm using #

# %% [markdown]
# #### Karen López Riojas
# Bioinformatic Researcher

# %% [markdown]
# ##### I'm interesting in Data Science because I want to be able to work with big data bases that could help me to build AI models to predict experiments and in that way save resources during lab experiments and time. All in the name of the enviorenment and science!

# %% [markdown]
# ### My code in cell 5 should show me the answer of the adding 10 + 5

# %%
10 + 5

# %% [markdown]
# <table style>
#   <tr>
#     <td>Kittens</td>
#       <td><a> Hi!</a></td>
#     <td> :3 </td>
#   </tr>
#     <tr>
#     <td>This is the 1st cell</td>
#     <td><img src="http://4.bp.blogspot.com/-WDNY9ykwPSM/VV6hYF-PtvI/AAAAAAAAD2M/8uNcSmn93LQ/s1600/gato-maine-coon.jpg"></td>
#     <td>This is the 3th cell</td>
#   </tr>
# </table>
# </html>
#
# <p>Here is a quote from WWF's website:</p>
#
# <blockquote cite="http://www.worldwildlife.org/who/index.html">
# For 60 years, WWF has worked to help people and nature thrive. As the world's leading conservation organization, WWF works in nearly 100 countries. At every level, we collaborate with people around the world to develop and deliver innovative solutions that protect communities, wildlife, and the places in which they live.
# </blockquote>
